# %% [markdown]
# <a href="https://colab.research.google.com/github/JasonKilembe/Certificats/blob/master/Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  ** Exploratory Data Analysis ** **bold text**

# %% [markdown]
# ## **Install conda and rdkit**

# %%
! wget https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.2-Linux-x86_64.sh
! chmod +x Miniconda3-py37_4.8.2-Linux-x86_64.sh
! bash ./Miniconda3-py37_4.8.2-Linux-x86_64.sh -b -f -p /usr/local
! conda install -c rdkit rdkit -y
import sys
sys.path.append('/usr/local/lib/python3.7/site-packages/')
# Out:
# --2025-08-25 10:18:12--  https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.2-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.32.241, 104.16.191.158, 2606:4700::6810:bf9e, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.32.241|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 85055499 (81M) [application/x-sh]
# Saving to: ‘Miniconda3-py37_4.8.2-Linux-x86_64.sh’
#
# Miniconda3-py37_4.8 100%[===================>]  81.12M   151MB/s    in 0.5s
#
# 2025-08-25 10:18:13 (151 MB/s) - ‘Miniconda3-py37_4.8.2-Linux-x86_64.sh’ saved [85055499/85055499]
#
# PREFIX=/usr/local
# Unpacking payload ...
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - _libgcc_mutex==0.1=main
#     - asn1crypto==1.3.0=py37_0
#     - ca-certificates==2020.1.1=0
#     - certifi==2019.11.28=py37_0
#     - cffi==1.14.0=py37h2e261b9_0
#     - chardet==3.0.4=py37_1003
# ...

# %% [markdown]
# ## **Load bioactivity data**

# %%
! wget https://raw.githubusercontent.com/dataprofessor/data/master/acetylcholinesterase_03_bioactivity_data_curated.csv
# Out:
# --2020-06-09 15:45:12--  https://raw.githubusercontent.com/dataprofessor/data/master/acetylcholinesterase_03_bioactivity_data_curated.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 385924 (377K) [text/plain]
# Saving to: ‘acetylcholinesterase_03_bioactivity_data_curated.csv’
#
# acetylcholinesteras 100%[===================>] 376.88K  --.-KB/s    in 0.03s
#
# 2020-06-09 15:45:13 (10.7 MB/s) - ‘acetylcholinesterase_03_bioactivity_data_curated.csv’ saved [385924/385924]

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/Last-Data_AR_data.csv')
df
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL134277  CC1=CC(C)(C)Nc2ccc3c(c21)/C(=C/c1ccsc1)Oc1ccc(...
# 1          CHEMBL146794  CC1(C)C(=O)N(c2ccc(C#N)c(C(F)(F)F)c2)C(=O)N1CC...
# 2         CHEMBL2112885  COc1cccc2c1C(=O)c1c(O)c3c(c(O)c1C2=O)C[C@@](O)...
# 3          CHEMBL336353  CC1=CC(C)(C)Nc2ccc3c(c21)/C(=C/c1ccccc1N(C)C)O...
# 4          CHEMBL413309  CC1=CC(C)(C)Nc2ccc3c(c21)/C(=C/c1ccccc1)Oc1c(F...
# ...                 ...                                                ...
# 3704      CHEMBL5401872                 CSc1ccc(C(=O)N2CCCCC2)cc1-c1cncnc1
# 3705      CHEMBL5394108                 CSc1ccc(C(=O)N2CCOCC2)cc1-c1cncnc1
# 3706      CHEMBL1082407  CNC(=O)c1ccc(N2C(=S)N(c3ccc(C#N)c(C(F)(F)F)c3)...
# 3707      CHEMBL5429958                         CSc1ccc(C(N)=O)cc1-c1ccno1
# 3708      CHEMBL4758041       CC(C)(c1ccc(OCC(O)CO)cc1)c1ccc(OCC(O)CCl)cc1
#
#      bioactivity_class  standard_value
# ...

# %%
df_clean_smiles_no_duplicates = df_clean_smiles.drop_duplicates(subset=['canonical_smiles'])
df_clean_smiles_no_duplicates
# Out:
#      molecule_chembl_id bioactivity_class  standard_value  \
# 0          CHEMBL134277            active           215.0
# 1          CHEMBL146794            active            77.0
# 2         CHEMBL2112885            active            90.0
# 3          CHEMBL336353      intermediate          1500.0
# 4          CHEMBL413309            active           900.0
# ...                 ...               ...             ...
# 3702      CHEMBL5405492          inactive         30000.0
# 3703      CHEMBL5424031            active           120.0
# 3704      CHEMBL5401872            active           130.0
# 3705      CHEMBL5394108            active           260.0
# 3707      CHEMBL5429958      intermediate          7400.0
#
#                                        canonical_smiles
# 0     CC1=CC(C)(C)Nc2ccc3c(c21)/C(=C/c1ccsc1)Oc1ccc(...
# 1     CC1(C)C(=O)N(c2ccc(C#N)c(C(F)(F)F)c2)C(=O)N1CC...
# 2     COc1cccc2c1C(=O)c1c(O)c3c(c(O)c1C2=O)C[C@@](O)...
# ...

# %%
df4 =pd.read_csv('/content/Last-Data_AR_data_cleaned.csv')
df4
# Out:
#      molecule_chembl_id bioactivity_class  standard_value  \
# 0          CHEMBL134277            active           215.0
# 1          CHEMBL146794            active            77.0
# 2         CHEMBL2112885            active            90.0
# 3          CHEMBL336353      intermediate          1500.0
# 4          CHEMBL413309            active           900.0
# ...                 ...               ...             ...
# 2537      CHEMBL5405492          inactive         30000.0
# 2538      CHEMBL5424031            active           120.0
# 2539      CHEMBL5401872            active           130.0
# 2540      CHEMBL5394108            active           260.0
# 2541      CHEMBL5429958      intermediate          7400.0
#
#                                        canonical_smiles
# 0     CC1=CC(C)(C)Nc2ccc3c(c21)/C(=C/c1ccsc1)Oc1ccc(...
# 1     CC1(C)C(=O)N(c2ccc(C#N)c(C(F)(F)F)c2)C(=O)N1CC...
# 2     COc1cccc2c1C(=O)c1c(O)c3c(c(O)c1C2=O)C[C@@](O)...
# ...

# %%
df_no_smiles = df4.drop(columns='canonical_smiles')
df_no_smiles
# Out:
#      molecule_chembl_id bioactivity_class  standard_value
# 0          CHEMBL134277            active           215.0
# 1          CHEMBL146794            active            77.0
# 2         CHEMBL2112885            active            90.0
# 3          CHEMBL336353      intermediate          1500.0
# 4          CHEMBL413309            active           900.0
# ...                 ...               ...             ...
# 2537      CHEMBL5405492          inactive         30000.0
# 2538      CHEMBL5424031            active           120.0
# 2539      CHEMBL5401872            active           130.0
# 2540      CHEMBL5394108            active           260.0
# 2541      CHEMBL5429958      intermediate          7400.0
#
# [2542 rows x 3 columns]

# %%
smiles = []
for i in df.canonical_smiles.tolist():
  cpd = str(i).split('.')
  cpd_longest = max(cpd, key = len)
  smiles.append(cpd_longest)

smiles = pd.Series(smiles, name = 'canonical_smiles')

# %%
df_clean_smiles_no_duplicates.to_csv('Last-Data_AR_data_cleaned.csv', index=False)

# %%
df_AR_clean_smiles = pd.concat([df_no_smiles,smiles], axis=1)
df_AR_clean_smiles
# Out:
#      molecule_chembl_id bioactivity_class  standard_value  \
# 0          CHEMBL134277            active           215.0
# 1          CHEMBL146794            active            77.0
# 2         CHEMBL2112885            active            90.0
# 3          CHEMBL336353      intermediate          1500.0
# 4          CHEMBL413309            active           900.0
# ...                 ...               ...             ...
# 3704                NaN               NaN             NaN
# 3705                NaN               NaN             NaN
# 3706                NaN               NaN             NaN
# 3707                NaN               NaN             NaN
# 3708                NaN               NaN             NaN
#
#                                        canonical_smiles
# 0     CC1=CC(C)(C)Nc2ccc3c(c21)/C(=C/c1ccsc1)Oc1ccc(...
# 1     CC1(C)C(=O)N(c2ccc(C#N)c(C(F)(F)F)c2)C(=O)N1CC...
# 2     COc1cccc2c1C(=O)c1c(O)c3c(c(O)c1C2=O)C[C@@](O)...
# ...

# %% [markdown]
# ## **Calculate Lipinski descriptors**
# Christopher Lipinski, a scientist at Pfizer, came up with a set of rule-of-thumb for evaluating the **druglikeness** of compounds. Such druglikeness is based on the Absorption, Distribution, Metabolism and Excretion (ADME) that is also known as the pharmacokinetic profile. Lipinski analyzed all orally active FDA-approved drugs in the formulation of what is to be known as the **Rule-of-Five** or **Lipinski's Rule**.
#
# The Lipinski's Rule stated the following:
# * Molecular weight < 500 Dalton
# * Octanol-water partition coefficient (LogP) < 5
# * Hydrogen bond donors < 5
# * Hydrogen bond acceptors < 10

# %% [markdown]
# ### **Import libraries**

# %%
# !pip install rdkit

# %%
import numpy as np
from rdkit import Chem
from rdkit.Chem import Descriptors, Lipinski

# %% [markdown]
# ### **Calculate descriptors**

# %%
# Inspired by: https://codeocean.com/explore/capsules?query=tag:data-curation

def lipinski(smiles, verbose=False):

    moldata= []
    for elem in smiles:
        mol=Chem.MolFromSmiles(elem)
        moldata.append(mol)

    baseData= np.arange(1,1)
    i=0
    for mol in moldata:

        desc_MolWt = Descriptors.MolWt(mol)
        desc_MolLogP = Descriptors.MolLogP(mol)
        desc_NumHDonors = Lipinski.NumHDonors(mol)
        desc_NumHAcceptors = Lipinski.NumHAcceptors(mol)

        row = np.array([desc_MolWt,
                        desc_MolLogP,
                        desc_NumHDonors,
                        desc_NumHAcceptors])

        if(i==0):
            baseData=row
        else:
            baseData=np.vstack([baseData, row])
        i=i+1

    columnNames=["MW","LogP","NumHDonors","NumHAcceptors"]
    descriptors = pd.DataFrame(data=baseData,columns=columnNames)

    return descriptors

# %%
df_lipinski = lipinski(df_AR_clean_smiles.canonical_smiles)
df_lipinski
# Out:
#             MW     LogP  NumHDonors  NumHAcceptors
# 0      389.495  7.05210         1.0            3.0
# 1      534.491  3.16218         2.0            7.0
# 2     1069.996  3.38318         8.0           18.0
# 3      426.535  7.05660         1.0            3.0
# 4      383.466  6.99060         1.0            2.0
# ...        ...      ...         ...            ...
# 3704   313.426  3.49160         0.0            4.0
# 3705   315.398  2.33790         0.0            5.0
# 3706   464.444  3.99248         1.0            4.0
# 3707   234.280  2.16240         1.0            4.0
# 3708   394.895  2.72300         3.0            5.0
#
# [3709 rows x 4 columns]

# %% [markdown]
# ### **Combine DataFrames**
#
# Let's take a look at the 2 DataFrames that will be combined.

# %%
df_lipinski
# Out:
#             MW     LogP  NumHDonors  NumHAcceptors
# 0      389.495  7.05210         1.0            3.0
# 1      534.491  3.16218         2.0            7.0
# 2     1069.996  3.38318         8.0           18.0
# 3      426.535  7.05660         1.0            3.0
# 4      383.466  6.99060         1.0            2.0
# ...        ...      ...         ...            ...
# 3704   313.426  3.49160         0.0            4.0
# 3705   315.398  2.33790         0.0            5.0
# 3706   464.444  3.99248         1.0            4.0
# 3707   234.280  2.16240         1.0            4.0
# 3708   394.895  2.72300         3.0            5.0
#
# [3709 rows x 4 columns]

# %%
df4
# Out:
#      molecule_chembl_id bioactivity_class  standard_value  \
# 0          CHEMBL134277            active           215.0
# 1          CHEMBL146794            active            77.0
# 2         CHEMBL2112885            active            90.0
# 3          CHEMBL336353      intermediate          1500.0
# 4          CHEMBL413309            active           900.0
# ...                 ...               ...             ...
# 2537      CHEMBL5405492          inactive         30000.0
# 2538      CHEMBL5424031            active           120.0
# 2539      CHEMBL5401872            active           130.0
# 2540      CHEMBL5394108            active           260.0
# 2541      CHEMBL5429958      intermediate          7400.0
#
#                                        canonical_smiles
# 0     CC1=CC(C)(C)Nc2ccc3c(c21)/C(=C/c1ccsc1)Oc1ccc(...
# 1     CC1(C)C(=O)N(c2ccc(C#N)c(C(F)(F)F)c2)C(=O)N1CC...
# 2     COc1cccc2c1C(=O)c1c(O)c3c(c(O)c1C2=O)C[C@@](O)...
# ...

# %% [markdown]
# Now, let's combine the 2 DataFrame

# %%
df_combined = pd.concat([df4,df_lipinski], axis=1)

# %%
df_combined
# Out:
#      molecule_chembl_id bioactivity_class  standard_value  \
# 0          CHEMBL134277            active           215.0
# 1          CHEMBL146794            active            77.0
# 2         CHEMBL2112885            active            90.0
# 3          CHEMBL336353      intermediate          1500.0
# 4          CHEMBL413309            active           900.0
# ...                 ...               ...             ...
# 3704                NaN               NaN             NaN
# 3705                NaN               NaN             NaN
# 3706                NaN               NaN             NaN
# 3707                NaN               NaN             NaN
# 3708                NaN               NaN             NaN
#
#                                        canonical_smiles        MW     LogP  \
# 0     CC1=CC(C)(C)Nc2ccc3c(c21)/C(=C/c1ccsc1)Oc1ccc(...   389.495  7.05210
# 1     CC1(C)C(=O)N(c2ccc(C#N)c(C(F)(F)F)c2)C(=O)N1CC...   534.491  3.16218
# ...

# %% [markdown]
# ### **Convert IC50 to pIC50**
# To allow **IC50** data to be more uniformly distributed, we will convert **IC50** to the negative logarithmic scale which is essentially **-log10(IC50)**.
#
# This custom function pIC50() will accept a DataFrame as input and will:
# * Take the IC50 values from the ``standard_value`` column and converts it from nM to M by multiplying the value by 10$^{-9}$
# * Take the molar value and apply -log10
# * Delete the ``standard_value`` column and create a new ``pIC50`` column

# %%
# https://github.com/chaninlab/estrogen-receptor-alpha-qsar/blob/master/02_ER_alpha_RO5.ipynb

import numpy as np

def pIC50(input):
    pIC50 = []

    for i in input['standard_value_norm']:
        molar = i*(10**-9) # Converts nM to M
        pIC50.append(-np.log10(molar))

    input['pIC50'] = pIC50
    x = input.drop('standard_value_norm', axis=1)

    return x

# %%
import numpy as np

# %% [markdown]
# Point to note: Values greater than 100,000,000 will be fixed at 100,000,000 otherwise the negative logarithmic value will become negative.

# %%
df_combined.standard_value.describe()
# Out:
# count    2.542000e+03
# mean     8.831045e+03
# std      4.873033e+04
# min      0.000000e+00
# 25%      1.047825e+02
# 50%      7.420000e+02
# 75%      5.360000e+03
# max      1.600000e+06
# Name: standard_value, dtype: float64

# %%
-np.log10( (10**-9)* 100000000 )
# Out:
# np.float64(1.0)

# %%
-np.log10( (10**-9)* 10000000000 )
# Out:
# np.float64(-1.0)

# %%
def norm_value(input):
    norm = []

    for i in input['standard_value']:
        if i > 100000000:
          i = 100000000
        norm.append(i)

    input['standard_value_norm'] = norm
    x = input.drop('standard_value', axis=1)

    return x

# %% [markdown]
# We will first apply the norm_value() function so that the values in the standard_value column is normalized.

# %%
df_norm = norm_value(df_combined)
df_norm
# Out:
#      molecule_chembl_id bioactivity_class  \
# 0          CHEMBL134277            active
# 1          CHEMBL146794            active
# 2         CHEMBL2112885            active
# 3          CHEMBL336353      intermediate
# 4          CHEMBL413309            active
# ...                 ...               ...
# 3704                NaN               NaN
# 3705                NaN               NaN
# 3706                NaN               NaN
# 3707                NaN               NaN
# 3708                NaN               NaN
#
#                                        canonical_smiles        MW     LogP  \
# 0     CC1=CC(C)(C)Nc2ccc3c(c21)/C(=C/c1ccsc1)Oc1ccc(...   389.495  7.05210
# 1     CC1(C)C(=O)N(c2ccc(C#N)c(C(F)(F)F)c2)C(=O)N1CC...   534.491  3.16218
# 2     COc1cccc2c1C(=O)c1c(O)c3c(c(O)c1C2=O)C[C@@](O)...  1069.996  3.38318
# 3     CC1=CC(C)(C)Nc2ccc3c(c21)/C(=C/c1ccccc1N(C)C)O...   426.535  7.05660
# 4     CC1=CC(C)(C)Nc2ccc3c(c21)/C(=C/c1ccccc1)Oc1c(F...   383.466  6.99060
# ...

# %%
df5 = pd.read_excel('/content/AR_bioactivity_data_3class_pIC50.csv')
df5
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-2494513088.py in <cell line: 0>()
# ----> 1 df5 = pd.read_excel('/content/AR_bioactivity_data_3class_pIC50.csv')
#       2 df5
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493     if not isinstance(io, ExcelFile):
#     494         should_close = True
# --> 495         io = ExcelFile(
#     496             io,
#     497             storage_options=storage_options,
#
# ...

# %%
df_norm.standard_value_norm.describe()
# Out:
# count    2.542000e+03
# mean     8.831045e+03
# std      4.873033e+04
# min      0.000000e+00
# 25%      1.047825e+02
# 50%      7.420000e+02
# 75%      5.360000e+03
# max      1.600000e+06
# Name: standard_value_norm, dtype: float64

# %%
df_final = pIC50(df_norm)
df_final
# Out:
# /tmp/ipython-input-3997281295.py:10: RuntimeWarning: divide by zero encountered in log10
#   pIC50.append(-np.log10(molar))
#      molecule_chembl_id bioactivity_class  \
# 0          CHEMBL134277            active
# 1          CHEMBL146794            active
# 2         CHEMBL2112885            active
# 3          CHEMBL336353      intermediate
# 4          CHEMBL413309            active
# ...                 ...               ...
# 3704                NaN               NaN
# 3705                NaN               NaN
# 3706                NaN               NaN
# 3707                NaN               NaN
# 3708                NaN               NaN
#
#                                        canonical_smiles        MW     LogP  \
# 0     CC1=CC(C)(C)Nc2ccc3c(c21)/C(=C/c1ccsc1)Oc1ccc(...   389.495  7.05210
# 1     CC1(C)C(=O)N(c2ccc(C#N)c(C(F)(F)F)c2)C(=O)N1CC...   534.491  3.16218
# 2     COc1cccc2c1C(=O)c1c(O)c3c(c(O)c1C2=O)C[C@@](O)...  1069.996  3.38318
# ...

# %%
df_final.pIC50.describe()
# Out:
# count    2542.000000
# mean             inf
# std              NaN
# min         2.795880
# 25%         5.270837
# 50%         6.129598
# 75%         6.979712
# max              inf
# Name: pIC50, dtype: float64

# %% [markdown]
# Let's write this to CSV file.

# %%
df_final.to_csv('AR_bioactivity_data_3class_pIC50.csv')

# %% [markdown]
# ### **Removing the 'intermediate' bioactivity class**
# Here, we will be removing the ``intermediate`` class from our data set.

# %%
# Out:
#      molecule_chembl_id  ...     pIC50
# 0          CHEMBL133897  ...  6.124939
# 1          CHEMBL336398  ...  7.000000
# 2          CHEMBL131588  ...  4.301030
# 3          CHEMBL130628  ...  6.522879
# 4          CHEMBL130478  ...  6.096910
# ...                 ...  ...       ...
# 4675      CHEMBL4284261  ...  3.015428
# 4676      CHEMBL4276921  ...  2.813467
# 4677      CHEMBL4292574  ...  3.476904
# 4685      CHEMBL4292766  ...  6.124939
# 4687      CHEMBL4284475  ...  6.008774
#
# [3549 rows x 8 columns]

# %% [markdown]
# Let's write this to CSV file.

# %% [markdown]
# ---

# %%
df_6 = pd.read_csv('/content/cleaned_canonical_smiles_comma.csv')
df_6
# Out:
#       Column1 molecule_chembl_id bioactivity_class  \
# 0           0       CHEMBL134277            active
# 1           1       CHEMBL146794            active
# 2           2      CHEMBL2112885            active
# 3           3       CHEMBL336353      intermediate
# 4           4       CHEMBL413309            active
# ...       ...                ...               ...
# 2537     2537      CHEMBL5405492          inactive
# 2538     2538      CHEMBL5424031            active
# 2539     2539      CHEMBL5401872            active
# 2540     2540      CHEMBL5394108            active
# 2541     2541      CHEMBL5429958      intermediate
#
#                                        canonical_smiles        MW     LogP  \
# 0     CC1=CC(C)(C)Nc2ccc3c(c21)/C(=C/c1ccsc1)Oc1ccc(...   389.495  7.05210
# 1     CC1(C)C(=O)N(c2ccc(C#N)c(C(F)(F)F)c2)C(=O)N1CC...   534.491  3.16218
# 2     COc1cccc2c1C(=O)c1c(O)c3c(c(O)c1C2=O)C[C@@](O)...  1069.996  3.38318
# ...

# %%
df_2class = df_6[df_final['bioactivity_class'] != 'intermediate']
df_2class
# Out:
# /tmp/ipython-input-2843376686.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_2class = df_6[df_final['bioactivity_class'] != 'intermediate']

# %%
df_2class
# Out:
#       Column1 molecule_chembl_id bioactivity_class  \
# 0           0       CHEMBL134277            active
# 1           1       CHEMBL146794            active
# 2           2      CHEMBL2112885            active
# 4           4       CHEMBL413309            active
# 5           5        CHEMBL27577            active
# ...       ...                ...               ...
# 2536     2536      CHEMBL5416300            active
# 2537     2537      CHEMBL5405492          inactive
# 2538     2538      CHEMBL5424031            active
# 2539     2539      CHEMBL5401872            active
# 2540     2540      CHEMBL5394108            active
#
#                                        canonical_smiles        MW     LogP  \
# 0     CC1=CC(C)(C)Nc2ccc3c(c21)/C(=C/c1ccsc1)Oc1ccc(...   389.495  7.05210
# 1     CC1(C)C(=O)N(c2ccc(C#N)c(C(F)(F)F)c2)C(=O)N1CC...   534.491  3.16218
# 2     COc1cccc2c1C(=O)c1c(O)c3c(c(O)c1C2=O)C[C@@](O)...  1069.996  3.38318
# ...

# %% [markdown]
# ## **Exploratory Data Analysis (Chemical Space Analysis) via Lipinski descriptors**

# %% [markdown]
# ### **Import library**

# %%
import seaborn as sns
sns.set(style='ticks')
import matplotlib.pyplot as plt

# %% [markdown]
# ### **Frequency plot of the 2 bioactivity classes**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(5.5, 5.5))

# Assign custom colors for each class
palette = {
    "active": "green",
    "inactive": "red",
    "intermediate": "orange"  # optional if you have this class
}

sns.countplot(
    x="bioactivity_class",
    data=df_2class,
    edgecolor="black",
    palette=palette
)

plt.xlabel("Bioactivity class", fontsize=14, fontweight="bold")
plt.ylabel("Frequency", fontsize=14, fontweight="bold")

plt.savefig("plot_bioactivity_class.pdf")
plt.show()
# Out:
# /tmp/ipython-input-3804528891.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(

# %% [markdown]
# ### **Scatter plot of MW versus LogP**
#
# It can be seen that the 2 bioactivity classes are spanning similar chemical spaces as evident by the scatter plot of MW vs LogP.

# %%
plt.figure(figsize=(5.5, 5.5))

sns.scatterplot(x='MW', y='LogP', data=df_2class, hue='bioactivity_class', size='pIC50', edgecolor='black', alpha=0.7)

plt.xlabel('MW', fontsize=14, fontweight='bold')
plt.ylabel('LogP', fontsize=14, fontweight='bold')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0)
plt.savefig('plot_MW_vs_LogP.pdf')
# Out:
# /usr/local/lib/python3.12/dist-packages/matplotlib/colors.py:2294: RuntimeWarning: invalid value encountered in divide
#   resdat /= (vmax - vmin)
# /usr/local/lib/python3.12/dist-packages/matplotlib/colors.py:2294: RuntimeWarning: invalid value encountered in divide
#   resdat /= (vmax - vmin)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-2346658910.py in <cell line: 0>()
#       6 plt.ylabel('LogP', fontsize=14, fontweight='bold')
#       7 plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0)
# ----> 8 plt.savefig('plot_MW_vs_LogP.pdf')
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#    1241     # savefig default implementation has no return, so mypy is unhappy
#    1242     # presumably this is here because subclasses can return?
# ...

# %% [markdown]
# ### **Box plots**

# %% [markdown]
# #### **pIC50 value**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(5.5, 5.5))

# Custom colors
palette = {
    "active": "green",
    "inactive": "red",
    "intermediate": "orange"  # only if you have this class
}

sns.boxplot(
    x="bioactivity_class",
    y="pIC50",
    data=df_2class,
    palette=palette
)

plt.xlabel("Bioactivity class", fontsize=14, fontweight="bold")
plt.ylabel("pIC50 value", fontsize=14, fontweight="bold")

plt.savefig("plot_ic50.pdf")
plt.show()
# Out:
# /tmp/ipython-input-3659159566.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(

# %% [markdown]
# **Statistical analysis | Mann-Whitney U Test**

# %%
def mannwhitney(descriptor, verbose=False):
  # https://machinelearningmastery.com/nonparametric-statistical-significance-tests-in-python/
  from numpy.random import seed
  from numpy.random import randn
  from scipy.stats import mannwhitneyu

# seed the random number generator
  seed(1)

# actives and inactives
  selection = [descriptor, 'bioactivity_class']
  df = df_2class[selection]
  active = df[df['bioactivity_class'] == 'active']
  active = active[descriptor]

  selection = [descriptor, 'bioactivity_class']
  df = df_2class[selection]
  inactive = df[df['bioactivity_class'] == 'inactive']
  inactive = inactive[descriptor]

# compare samples
  stat, p = mannwhitneyu(active, inactive)
  #print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
  alpha = 0.05
  if p > alpha:
    interpretation = 'Same distribution (fail to reject H0)'
  else:
    interpretation = 'Different distribution (reject H0)'

  results = pd.DataFrame({'Descriptor':descriptor,
                          'Statistics':stat,
                          'p':p,
                          'alpha':alpha,
                          'Interpretation':interpretation}, index=[0])
  filename = 'mannwhitneyu_' + descriptor + '.csv'
  results.to_csv(filename)

  return results

# %%
mannwhitney('pIC50')
# Out:
#   Descriptor  Statistics              p  alpha  \
# 0      pIC50    727180.0  8.900977e-249   0.05
#
#                        Interpretation
# 0  Different distribution (reject H0)

# %% [markdown]
# #### **MW**

# %%
plt.figure(figsize=(5.5, 5.5))

sns.boxplot(x = 'bioactivity_class', y = 'MW', data = df_2class)

plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
plt.ylabel('MW', fontsize=14, fontweight='bold')

plt.savefig('plot_MW.pdf')

# %%
mannwhitney('MW')
# Out:
#   Descriptor  Statistics         p  alpha  \
# 0         MW    369531.5  0.582565   0.05
#
#                           Interpretation
# 0  Same distribution (fail to reject H0)

# %% [markdown]
# #### **LogP**

# %%
plt.figure(figsize=(5.5, 5.5))

sns.boxplot(x = 'bioactivity_class', y = 'LogP', data = df_2class)

plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
plt.ylabel('LogP', fontsize=14, fontweight='bold')

plt.savefig('plot_LogP.pdf')

# %% [markdown]
# **Statistical analysis | Mann-Whitney U Test**

# %%
mannwhitney('LogP')
# Out:
#   Descriptor  Statistics         p  alpha  \
# 0       LogP    375337.5  0.277129   0.05
#
#                           Interpretation
# 0  Same distribution (fail to reject H0)

# %% [markdown]
# #### **NumHDonors**

# %%
plt.figure(figsize=(5.5, 5.5))

sns.boxplot(x = 'bioactivity_class', y = 'NumHDonors', data = df_2class)

plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
plt.ylabel('NumHDonors', fontsize=14, fontweight='bold')

plt.savefig('plot_NumHDonors.pdf')

# %% [markdown]
# **Statistical analysis | Mann-Whitney U Test**

# %%
mannwhitney('NumHDonors')
# Out:
#    Descriptor  Statistics         p  alpha                      Interpretation
# 0  NumHDonors    388150.5  0.015036   0.05  Different distribution (reject H0)

# %% [markdown]
# #### **NumHAcceptors**

# %%
plt.figure(figsize=(5.5, 5.5))

sns.boxplot(x = 'bioactivity_class', y = 'NumHAcceptors', data = df_2class)

plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
plt.ylabel('NumHAcceptors', fontsize=14, fontweight='bold')

plt.savefig('plot_NumHAcceptors.pdf')

# %%
mannwhitney('NumHAcceptors')
# Out:
#       Descriptor  Statistics         p  alpha  \
# 0  NumHAcceptors    371122.5  0.474308   0.05
#
#                           Interpretation
# 0  Same distribution (fail to reject H0)

# %% [markdown]
# #### **Interpretation of Statistical Results**

# %% [markdown]
# ##### **Box Plots**
#
# ###### **pIC50 values**
#
# Taking a look at pIC50 values, the **actives** and **inactives** displayed ***statistically significant difference***, which is to be expected since threshold values (``IC50 < 1,000 nM = Actives while IC50 > 10,000 nM = Inactives``, corresponding to ``pIC50 > 6 = Actives and pIC50 < 5 = Inactives``) were used to define actives and inactives.
#
# ###### **Lipinski's descriptors**
#
# All of the 4 Lipinski's descriptors exhibited ***statistically significant difference*** between the **actives** and **inactives**.

# %% [markdown]
# ## **Zip files**

# %%
! zip -r results.zip . -i *.csv *.pdf
# Out:
#   adding: Last-Data_AR_data_cleaned.csv (deflated 83%)
#   adding: plot_MW.pdf (deflated 39%)
#   adding: cleaned_canonical_smiles.csv (deflated 79%)
#   adding: plot_NumHDonors.pdf (deflated 37%)
#   adding: mannwhitneyu_LogP.csv (deflated 8%)
#   adding: cleaned_canonical_smiles_comma.csv (deflated 79%)
#   adding: plot_NumHAcceptors.pdf (deflated 39%)
#   adding: mannwhitneyu_pIC50.csv (deflated 11%)
#   adding: mannwhitneyu_NumHDonors.csv (deflated 11%)
#   adding: plot_bioactivity_class.pdf (deflated 38%)
#   adding: mannwhitneyu_NumHAcceptors.csv (deflated 9%)
#   adding: plot_ic50.pdf (deflated 36%)
#   adding: plot_MW_vs_LogP.pdf (deflated 13%)
#   adding: plot_LogP.pdf (deflated 37%)
#   adding: mannwhitneyu_MW.csv (deflated 9%)
#   adding: Last-Data_AR_data.csv (deflated 86%)
